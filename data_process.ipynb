# %%
import pickle
from dataclasses import dataclass
from pathlib import Path

import miditok
import numpy as np
import torch
import torch.nn as nn
from midi_player import MIDIPlayer
from miditok import REMI, TokenizerConfig
from miditok.pytorch_data import DataCollator, DatasetMIDI
from torch.utils.data import DataLoader
import os
from tqdm import tqdm

# %% [markdown]
# ## Check original dataset format

# %%
# 'Beat_0': 1,
event2idx, idx2event = pickle.load(open('pickles/remi_vocab.pkl', 'rb'))
list(event2idx.keys())
# Out:
# ['Bar_None',
#  'Beat_0',
#  'Beat_1',
#  'Beat_10',
#  'Beat_11',
#  'Beat_12',
#  'Beat_13',
#  'Beat_14',
#  'Beat_15',
#  'Beat_2',
#  'Beat_3',
#  'Beat_4',
#  'Beat_5',
#  'Beat_6',
#  'Beat_7',
#  'Beat_8',
#  'Beat_9',
#  'Chord_A#_+',
#  'Chord_A#_/o7',
#  'Chord_A#_7',
#  'Chord_A#_M',
#  'Chord_A#_M7',
#  'Chord_A#_m',
#  'Chord_A#_m7',
#  'Chord_A#_o',
#  'Chord_A#_o7',
#  'Chord_A#_sus2',
#  'Chord_A#_sus4',
#  'Chord_A_+',
#  'Chord_A_/o7',
#  'Chord_A_7',
#  'Chord_A_M',
#  'Chord_A_M7',
#  'Chord_A_m',
#  'Chord_A_m7',
#  'Chord_A_o',
#  'Chord_A_o7',
#  'Chord_A_sus2',
#  'Chord_A_sus4',
#  'Chord_B_+',
#  'Chord_B_/o7',
#  'Chord_B_7',
#  'Chord_B_M',
#  'Chord_B_M7',
#  'Chord_B_m',
#  'Chord_B_m7',
#  'Chord_B_o',
#  'Chord_B_o7',
#  'Chord_B_sus2',
#  'Chord_B_sus4',
#  'Chord_C#_+',
#  'Chord_C#_/o7',
#  'Chord_C#_7',
#  'Chord_C#_M',
#  'Chord_C#_M7',
#  'Chord_C#_m',
#  'Chord_C#_m7',
#  'Chord_C#_o',
#  'Chord_C#_o7',
#  'Chord_C#_sus2',
#  'Chord_C#_sus4',
#  'Chord_C_+',
#  'Chord_C_/o7',
#  'Chord_C_7',
#  'Chord_C_M',
#  'Chord_C_M7',
#  'Chord_C_m',
#  'Chord_C_m7',
#  'Chord_C_o',
#  'Chord_C_o7',
#  'Chord_C_sus2',
#  'Chord_C_sus4',
#  'Chord_D#_+',
#  'Chord_D#_/o7',
#  'Chord_D#_7',
#  'Chord_D#_M',
#  'Chord_D#_M7',
#  'Chord_D#_m',
#  'Chord_D#_m7',
#  'Chord_D#_o',
#  'Chord_D#_o7',
#  'Chord_D#_sus2',
#  'Chord_D#_sus4',
#  'Chord_D_+',
#  'Chord_D_/o7',
#  'Chord_D_7',
#  'Chord_D_M',
#  'Chord_D_M7',
#  'Chord_D_m',
#  'Chord_D_m7',
#  'Chord_D_o',
#  'Chord_D_o7',
#  'Chord_D_sus2',
#  'Chord_D_sus4',
#  'Chord_E_+',
#  'Chord_E_/o7',
#  'Chord_E_7',
#  'Chord_E_M',
#  'Chord_E_M7',
#  'Chord_E_m',
#  'Chord_E_m7',
#  'Chord_E_o',
#  'Chord_E_o7',
#  'Chord_E_sus2',
#  'Chord_E_sus4',
#  'Chord_F#_+',
#  'Chord_F#_/o7',
#  'Chord_F#_7',
#  'Chord_F#_M',
#  'Chord_F#_M7',
#  'Chord_F#_m',
#  'Chord_F#_m7',
#  'Chord_F#_o',
#  'Chord_F#_o7',
#  'Chord_F#_sus2',
#  'Chord_F#_sus4',
#  'Chord_F_+',
#  'Chord_F_/o7',
#  'Chord_F_7',
#  'Chord_F_M',
#  'Chord_F_M7',
#  'Chord_F_m',
#  'Chord_F_m7',
#  'Chord_F_o',
#  'Chord_F_o7',
#  'Chord_F_sus2',
#  'Chord_F_sus4',
#  'Chord_G#_+',
#  'Chord_G#_/o7',
#  'Chord_G#_7',
#  'Chord_G#_M',
#  'Chord_G#_M7',
#  'Chord_G#_m',
#  'Chord_G#_m7',
#  'Chord_G#_o',
#  'Chord_G#_o7',
#  'Chord_G#_sus2',
#  'Chord_G#_sus4',
#  'Chord_G_+',
#  'Chord_G_/o7',
#  'Chord_G_7',
#  'Chord_G_M',
#  'Chord_G_M7',
#  'Chord_G_m',
#  'Chord_G_m7',
#  'Chord_G_o',
#  'Chord_G_o7',
#  'Chord_G_sus2',
#  'Chord_G_sus4',
#  'Chord_N_N',
#  'EOS_None',
#  'Note_Duration_0',
#  'Note_Duration_1080',
#  'Note_Duration_120',
#  'Note_Duration_1200',
#  'Note_Duration_1320',
#  'Note_Duration_1440',
#  'Note_Duration_1560',
#  'Note_Duration_1680',
#  'Note_Duration_1800',
#  'Note_Duration_1920',
#  'Note_Duration_240',
#  'Note_Duration_360',
#  'Note_Duration_480',
#  'Note_Duration_600',
#  'Note_Duration_720',
#  'Note_Duration_840',
#  'Note_Duration_960',
#  'Note_Pitch_100',
#  'Note_Pitch_101',
#  'Note_Pitch_102',
#  'Note_Pitch_103',
#  'Note_Pitch_104',
#  'Note_Pitch_105',
#  'Note_Pitch_106',
#  'Note_Pitch_107',
#  'Note_Pitch_22',
#  'Note_Pitch_23',
#  'Note_Pitch_24',
#  'Note_Pitch_25',
#  'Note_Pitch_26',
#  'Note_Pitch_27',
#  'Note_Pitch_28',
#  'Note_Pitch_29',
#  'Note_Pitch_30',
#  'Note_Pitch_31',
#  'Note_Pitch_32',
#  'Note_Pitch_33',
#  'Note_Pitch_34',
#  'Note_Pitch_35',
#  'Note_Pitch_36',
#  'Note_Pitch_37',
#  'Note_Pitch_38',
#  'Note_Pitch_39',
#  'Note_Pitch_40',
#  'Note_Pitch_41',
#  'Note_Pitch_42',
#  'Note_Pitch_43',
#  'Note_Pitch_44',
#  'Note_Pitch_45',
#  'Note_Pitch_46',
#  'Note_Pitch_47',
#  'Note_Pitch_48',
#  'Note_Pitch_49',
#  'Note_Pitch_50',
#  'Note_Pitch_51',
#  'Note_Pitch_52',
#  'Note_Pitch_53',
#  'Note_Pitch_54',
#  'Note_Pitch_55',
#  'Note_Pitch_56',
#  'Note_Pitch_57',
#  'Note_Pitch_58',
#  'Note_Pitch_59',
#  'Note_Pitch_60',
#  'Note_Pitch_61',
#  'Note_Pitch_62',
#  'Note_Pitch_63',
#  'Note_Pitch_64',
#  'Note_Pitch_65',
#  'Note_Pitch_66',
#  'Note_Pitch_67',
#  'Note_Pitch_68',
#  'Note_Pitch_69',
#  'Note_Pitch_70',
#  'Note_Pitch_71',
#  'Note_Pitch_72',
#  'Note_Pitch_73',
#  'Note_Pitch_74',
#  'Note_Pitch_75',
#  'Note_Pitch_76',
#  'Note_Pitch_77',
#  'Note_Pitch_78',
#  'Note_Pitch_79',
#  'Note_Pitch_80',
#  'Note_Pitch_81',
#  'Note_Pitch_82',
#  'Note_Pitch_83',
#  'Note_Pitch_84',
#  'Note_Pitch_85',
#  'Note_Pitch_86',
#  'Note_Pitch_87',
#  'Note_Pitch_88',
#  'Note_Pitch_89',
#  'Note_Pitch_90',
#  'Note_Pitch_91',
#  'Note_Pitch_92',
#  'Note_Pitch_93',
#  'Note_Pitch_94',
#  'Note_Pitch_95',
#  'Note_Pitch_96',
#  'Note_Pitch_97',
#  'Note_Pitch_98',
#  'Note_Pitch_99',
#  'Note_Velocity_40',
#  'Note_Velocity_42',
#  'Note_Velocity_44',
#  'Note_Velocity_46',
#  'Note_Velocity_48',
#  'Note_Velocity_50',
#  'Note_Velocity_52',
#  'Note_Velocity_54',
#  'Note_Velocity_56',
#  'Note_Velocity_58',
#  'Note_Velocity_60',
#  'Note_Velocity_62',
#  'Note_Velocity_64',
#  'Note_Velocity_66',
#  'Note_Velocity_68',
#  'Note_Velocity_70',
#  'Note_Velocity_72',
#  'Note_Velocity_74',
#  'Note_Velocity_76',
#  'Note_Velocity_78',
#  'Note_Velocity_80',
#  'Note_Velocity_82',
#  'Note_Velocity_84',
#  'Note_Velocity_86',
#  'Tempo_101',
#  'Tempo_104',
#  'Tempo_107',
#  'Tempo_110',
#  'Tempo_113',
#  'Tempo_116',
#  'Tempo_119',
#  'Tempo_122',
#  'Tempo_125',
#  'Tempo_128',
#  'Tempo_131',
#  'Tempo_134',
#  'Tempo_137',
#  'Tempo_140',
#  'Tempo_143',
#  'Tempo_146',
#  'Tempo_149',
#  'Tempo_155',
#  'Tempo_158',
#  'Tempo_161',
#  'Tempo_167',
#  'Tempo_170',
#  'Tempo_176',
#  'Tempo_182',
#  'Tempo_188',
#  'Tempo_194',
#  'Tempo_200',
#  'Tempo_206',
#  'Tempo_215',
#  'Tempo_221',
#  'Tempo_224',
#  'Tempo_32',
#  'Tempo_35',
#  'Tempo_38',
#  'Tempo_41',
#  'Tempo_44',
#  'Tempo_47',
#  'Tempo_50',
#  'Tempo_53',
#  'Tempo_56',
#  'Tempo_59',
#  'Tempo_62',
#  'Tempo_65',
#  'Tempo_68',
#  'Tempo_71',
#  'Tempo_74',
#  'Tempo_77',
#  'Tempo_80',
#  'Tempo_83',
#  'Tempo_86',
#  'Tempo_89',
#  'Tempo_92',
#  'Tempo_95',
#  'Tempo_98']

# %%
len(list(event2idx.keys()))
# Out:
# 332

# %%
len(pickle.load(open('pickles/train_pieces.pkl', 'rb')))
pickle.load(open('pickles/train_pieces.pkl', 'rb'))[0:10]
# Out:
# ['1398.pkl',
#  '954.pkl',
#  '848.pkl',
#  '1574.pkl',
#  '128.pkl',
#  '802.pkl',
#  '1255.pkl',
#  '1682.pkl',
#  '330.pkl',
#  '443.pkl']

# %%
ids, tokens = pickle.load(open('remi_dataset/1.pkl', 'rb'))

# [idx2event[_] for _ in ids if _ in idx2event]
# ids[-10:-1]
ids[0:10]
# tokens
# Out:
# [0, 54, 105, 143, 188, 247, 302, 361, 414, 465]

# %%
tokens
# Out:
# [{'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'N_N'},
#  {'name': 'Tempo', 'value': np.int64(119)},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(65)},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 5},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 7},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Tempo', 'value': np.int64(59)},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 9},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 11},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Tempo', 'value': np.int64(56)},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(54)},
#  {'name': 'Note_Duration', 'value': 1320},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'A#_7'},
#  {'name': 'Tempo', 'value': np.int64(56)},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 1},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 1800},
#  {'name': 'Beat', 'value': 3},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': np.int64(52)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(68)},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(54)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Tempo', 'value': np.int64(59)},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 11},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(65)},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 13},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Beat', 'value': 15},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Tempo', 'value': np.int64(86)},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Chord', 'value': 'D_+'},
#  {'name': 'Note_Pitch', 'value': 46},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 1920},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 1680},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A#_7'},
#  {'name': 'Tempo', 'value': np.int64(80)},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(83)},
#  {'name': 'Beat', 'value': 13},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'C_+'},
#  {'name': 'Tempo', 'value': np.int64(89)},
#  {'name': 'Beat', 'value': 3},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(89)},
#  {'name': 'Beat', 'value': 5},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M'},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(86)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F#_m7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 66},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'E_sus4'},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 1200},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 47},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(89)},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 1440},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'E_7'},
#  {'name': 'Tempo', 'value': np.int64(80)},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(77)},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(52)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 7},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F#_m7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 66},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'G#_m7'},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 1560},
#  {'name': 'Note_Pitch', 'value': 63},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 44},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 51},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(86)},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 59},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'C#_7'},
#  {'name': 'Tempo', 'value': np.int64(77)},
#  {'name': 'Note_Pitch', 'value': 55},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(54)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(80)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F#_m'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Note_Pitch', 'value': 68},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'C#_7'},
#  {'name': 'Tempo', 'value': np.int64(101)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 68},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'D#_/o7'},
#  {'name': 'Tempo', 'value': np.int64(89)},
#  {'name': 'Note_Pitch', 'value': 51},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Chord', 'value': 'G#_7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 63},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 44},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 51},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 80},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'C#_m7'},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 68},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 59},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(82)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F#_7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(80)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 58},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'B_m7'},
#  {'name': 'Tempo', 'value': np.int64(86)},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 66},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 47},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(74)},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'E_+'},
#  {'name': 'Tempo', 'value': np.int64(62)},
#  {'name': 'Note_Pitch', 'value': 75},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 0},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(74)},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 64},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 90},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 840},
#  {'name': 'Note_Pitch', 'value': 88},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F#_m7'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 42},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'B_m7'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 88},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 47},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Note_Pitch', 'value': 83},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 1080},
#  {'name': 'Note_Pitch', 'value': 74},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 62},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'E_m7'},
#  {'name': 'Tempo', 'value': np.int64(89)},
#  {'name': 'Note_Pitch', 'value': 40},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 50},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Chord', 'value': 'C_+'},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 90},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 60},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 76},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Note_Pitch', 'value': 88},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 45},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'F#_m7'},
#  {'name': 'Tempo', 'value': np.int64(95)},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 120},
#  {'name': 'Note_Pitch', 'value': 42},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'G#_m7'},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 83},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 75},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 44},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Note_Pitch', 'value': 78},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 960},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 51},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 59},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'C#_m7'},
#  {'name': 'Tempo', 'value': np.int64(86)},
#  {'name': 'Note_Pitch', 'value': 55},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 49},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Tempo', 'value': np.int64(83)},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 83},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(56)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'F#_m'},
#  {'name': 'Tempo', 'value': np.int64(98)},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 42},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 54},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Note_Pitch', 'value': 80},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 68},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(58)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 14},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(68)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Bar', 'value': None},
#  {'name': 'Beat', 'value': 0},
#  {'name': 'Chord', 'value': 'C#_7'},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 41},
#  {'name': 'Note_Velocity', 'value': np.int64(62)},
#  {'name': 'Note_Duration', 'value': 600},
#  {'name': 'Beat', 'value': 2},
#  {'name': 'Note_Pitch', 'value': 53},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 4},
#  {'name': 'Note_Pitch', 'value': 85},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 360},
#  {'name': 'Note_Pitch', 'value': 73},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 56},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 6},
#  {'name': 'Note_Pitch', 'value': 83},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 71},
#  {'name': 'Note_Velocity', 'value': np.int64(70)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 61},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Beat', 'value': 8},
#  {'name': 'Chord', 'value': 'A_M7'},
#  {'name': 'Tempo', 'value': np.int64(101)},
#  {'name': 'Note_Pitch', 'value': 81},
#  {'name': 'Note_Velocity', 'value': np.int64(78)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 69},
#  {'name': 'Note_Velocity', 'value': np.int64(74)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(66)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 40},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 480},
#  {'name': 'Beat', 'value': 10},
#  {'name': 'Note_Pitch', 'value': 52},
#  {'name': 'Note_Velocity', 'value': np.int64(64)},
#  {'name': 'Note_Duration', 'value': 720},
#  {'name': 'Beat', 'value': 12},
#  {'name': 'Tempo', 'value': np.int64(92)},
#  {'name': 'Note_Pitch', 'value': 80},
#  {'name': 'Note_Velocity', 'value': np.int64(76)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 68},
#  {'name': 'Note_Velocity', 'value': np.int64(72)},
#  {'name': 'Note_Duration', 'value': 240},
#  {'name': 'Note_Pitch', 'value': 57},
#  {'name': 'Note_Velocity', 'value': np.int64(60)},
#  {'name': 'Note_Duration', 'value': 480},
#  ...]

# %% [markdown]
# ## Tokenize Jazz dataset
#
# There are some event string format difference between the `remi_dataset` and event string produced from the miditok
#
# - 'Beat' vs 'Position'
# - 'Note_Pitch' vs 'Pitch'
# - 'Chord_B:7aug' vs 'Chord_A#_+'

# %%
tokenizer = REMI(
    TokenizerConfig(
        use_tempos=True, 
        use_pitchdrum_tokens=False, 
        chord_tokens_with_root_note=True,
        use_chords=True,
        beat_res={(0, 4): 16, (4, 12): 8},
    )
)

event2idx = tokenizer.vocab
idx2event = {v: k for k, v in event2idx.items()}

with open('jazz/meta/remi_vocab.pkl', 'wb') as handle:
    pickle.dump((event2idx, idx2event), handle, protocol=pickle.HIGHEST_PROTOCOL)

tokenizer.save("jazz/meta/remi_tokenizer.json")

# %%
len(tokenizer.vocab)
# Out:
# 517

# %%
tokenizer.vocab
# Out:
# {'PAD_None': 0,
#  'BOS_None': 1,
#  'EOS_None': 2,
#  'MASK_None': 3,
#  'Bar_None': 4,
#  'Pitch_21': 5,
#  'Pitch_22': 6,
#  'Pitch_23': 7,
#  'Pitch_24': 8,
#  'Pitch_25': 9,
#  'Pitch_26': 10,
#  'Pitch_27': 11,
#  'Pitch_28': 12,
#  'Pitch_29': 13,
#  'Pitch_30': 14,
#  'Pitch_31': 15,
#  'Pitch_32': 16,
#  'Pitch_33': 17,
#  'Pitch_34': 18,
#  'Pitch_35': 19,
#  'Pitch_36': 20,
#  'Pitch_37': 21,
#  'Pitch_38': 22,
#  'Pitch_39': 23,
#  'Pitch_40': 24,
#  'Pitch_41': 25,
#  'Pitch_42': 26,
#  'Pitch_43': 27,
#  'Pitch_44': 28,
#  'Pitch_45': 29,
#  'Pitch_46': 30,
#  'Pitch_47': 31,
#  'Pitch_48': 32,
#  'Pitch_49': 33,
#  'Pitch_50': 34,
#  'Pitch_51': 35,
#  'Pitch_52': 36,
#  'Pitch_53': 37,
#  'Pitch_54': 38,
#  'Pitch_55': 39,
#  'Pitch_56': 40,
#  'Pitch_57': 41,
#  'Pitch_58': 42,
#  'Pitch_59': 43,
#  'Pitch_60': 44,
#  'Pitch_61': 45,
#  'Pitch_62': 46,
#  'Pitch_63': 47,
#  'Pitch_64': 48,
#  'Pitch_65': 49,
#  'Pitch_66': 50,
#  'Pitch_67': 51,
#  'Pitch_68': 52,
#  'Pitch_69': 53,
#  'Pitch_70': 54,
#  'Pitch_71': 55,
#  'Pitch_72': 56,
#  'Pitch_73': 57,
#  'Pitch_74': 58,
#  'Pitch_75': 59,
#  'Pitch_76': 60,
#  'Pitch_77': 61,
#  'Pitch_78': 62,
#  'Pitch_79': 63,
#  'Pitch_80': 64,
#  'Pitch_81': 65,
#  'Pitch_82': 66,
#  'Pitch_83': 67,
#  'Pitch_84': 68,
#  'Pitch_85': 69,
#  'Pitch_86': 70,
#  'Pitch_87': 71,
#  'Pitch_88': 72,
#  'Pitch_89': 73,
#  'Pitch_90': 74,
#  'Pitch_91': 75,
#  'Pitch_92': 76,
#  'Pitch_93': 77,
#  'Pitch_94': 78,
#  'Pitch_95': 79,
#  'Pitch_96': 80,
#  'Pitch_97': 81,
#  'Pitch_98': 82,
#  'Pitch_99': 83,
#  'Pitch_100': 84,
#  'Pitch_101': 85,
#  'Pitch_102': 86,
#  'Pitch_103': 87,
#  'Pitch_104': 88,
#  'Pitch_105': 89,
#  'Pitch_106': 90,
#  'Pitch_107': 91,
#  'Pitch_108': 92,
#  'Velocity_3': 93,
#  'Velocity_7': 94,
#  'Velocity_11': 95,
#  'Velocity_15': 96,
#  'Velocity_19': 97,
#  'Velocity_23': 98,
#  'Velocity_27': 99,
#  'Velocity_31': 100,
#  'Velocity_35': 101,
#  'Velocity_39': 102,
#  'Velocity_43': 103,
#  'Velocity_47': 104,
#  'Velocity_51': 105,
#  'Velocity_55': 106,
#  'Velocity_59': 107,
#  'Velocity_63': 108,
#  'Velocity_67': 109,
#  'Velocity_71': 110,
#  'Velocity_75': 111,
#  'Velocity_79': 112,
#  'Velocity_83': 113,
#  'Velocity_87': 114,
#  'Velocity_91': 115,
#  'Velocity_95': 116,
#  'Velocity_99': 117,
#  'Velocity_103': 118,
#  'Velocity_107': 119,
#  'Velocity_111': 120,
#  'Velocity_115': 121,
#  'Velocity_119': 122,
#  'Velocity_123': 123,
#  'Velocity_127': 124,
#  'Duration_0.1.16': 125,
#  'Duration_0.2.16': 126,
#  'Duration_0.3.16': 127,
#  'Duration_0.4.16': 128,
#  'Duration_0.5.16': 129,
#  'Duration_0.6.16': 130,
#  'Duration_0.7.16': 131,
#  'Duration_0.8.16': 132,
#  'Duration_0.9.16': 133,
#  'Duration_0.10.16': 134,
#  'Duration_0.11.16': 135,
#  'Duration_0.12.16': 136,
#  'Duration_0.13.16': 137,
#  'Duration_0.14.16': 138,
#  'Duration_0.15.16': 139,
#  'Duration_1.0.16': 140,
#  'Duration_1.1.16': 141,
#  'Duration_1.2.16': 142,
#  'Duration_1.3.16': 143,
#  'Duration_1.4.16': 144,
#  'Duration_1.5.16': 145,
#  'Duration_1.6.16': 146,
#  'Duration_1.7.16': 147,
#  'Duration_1.8.16': 148,
#  'Duration_1.9.16': 149,
#  'Duration_1.10.16': 150,
#  'Duration_1.11.16': 151,
#  'Duration_1.12.16': 152,
#  'Duration_1.13.16': 153,
#  'Duration_1.14.16': 154,
#  'Duration_1.15.16': 155,
#  'Duration_2.0.16': 156,
#  'Duration_2.1.16': 157,
#  'Duration_2.2.16': 158,
#  'Duration_2.3.16': 159,
#  'Duration_2.4.16': 160,
#  'Duration_2.5.16': 161,
#  'Duration_2.6.16': 162,
#  'Duration_2.7.16': 163,
#  'Duration_2.8.16': 164,
#  'Duration_2.9.16': 165,
#  'Duration_2.10.16': 166,
#  'Duration_2.11.16': 167,
#  'Duration_2.12.16': 168,
#  'Duration_2.13.16': 169,
#  'Duration_2.14.16': 170,
#  'Duration_2.15.16': 171,
#  'Duration_3.0.16': 172,
#  'Duration_3.1.16': 173,
#  'Duration_3.2.16': 174,
#  'Duration_3.3.16': 175,
#  'Duration_3.4.16': 176,
#  'Duration_3.5.16': 177,
#  'Duration_3.6.16': 178,
#  'Duration_3.7.16': 179,
#  'Duration_3.8.16': 180,
#  'Duration_3.9.16': 181,
#  'Duration_3.10.16': 182,
#  'Duration_3.11.16': 183,
#  'Duration_3.12.16': 184,
#  'Duration_3.13.16': 185,
#  'Duration_3.14.16': 186,
#  'Duration_3.15.16': 187,
#  'Duration_4.0.8': 188,
#  'Duration_4.1.8': 189,
#  'Duration_4.2.8': 190,
#  'Duration_4.3.8': 191,
#  'Duration_4.4.8': 192,
#  'Duration_4.5.8': 193,
#  'Duration_4.6.8': 194,
#  'Duration_4.7.8': 195,
#  'Duration_5.0.8': 196,
#  'Duration_5.1.8': 197,
#  'Duration_5.2.8': 198,
#  'Duration_5.3.8': 199,
#  'Duration_5.4.8': 200,
#  'Duration_5.5.8': 201,
#  'Duration_5.6.8': 202,
#  'Duration_5.7.8': 203,
#  'Duration_6.0.8': 204,
#  'Duration_6.1.8': 205,
#  'Duration_6.2.8': 206,
#  'Duration_6.3.8': 207,
#  'Duration_6.4.8': 208,
#  'Duration_6.5.8': 209,
#  'Duration_6.6.8': 210,
#  'Duration_6.7.8': 211,
#  'Duration_7.0.8': 212,
#  'Duration_7.1.8': 213,
#  'Duration_7.2.8': 214,
#  'Duration_7.3.8': 215,
#  'Duration_7.4.8': 216,
#  'Duration_7.5.8': 217,
#  'Duration_7.6.8': 218,
#  'Duration_7.7.8': 219,
#  'Duration_8.0.8': 220,
#  'Duration_8.1.8': 221,
#  'Duration_8.2.8': 222,
#  'Duration_8.3.8': 223,
#  'Duration_8.4.8': 224,
#  'Duration_8.5.8': 225,
#  'Duration_8.6.8': 226,
#  'Duration_8.7.8': 227,
#  'Duration_9.0.8': 228,
#  'Duration_9.1.8': 229,
#  'Duration_9.2.8': 230,
#  'Duration_9.3.8': 231,
#  'Duration_9.4.8': 232,
#  'Duration_9.5.8': 233,
#  'Duration_9.6.8': 234,
#  'Duration_9.7.8': 235,
#  'Duration_10.0.8': 236,
#  'Duration_10.1.8': 237,
#  'Duration_10.2.8': 238,
#  'Duration_10.3.8': 239,
#  'Duration_10.4.8': 240,
#  'Duration_10.5.8': 241,
#  'Duration_10.6.8': 242,
#  'Duration_10.7.8': 243,
#  'Duration_11.0.8': 244,
#  'Duration_11.1.8': 245,
#  'Duration_11.2.8': 246,
#  'Duration_11.3.8': 247,
#  'Duration_11.4.8': 248,
#  'Duration_11.5.8': 249,
#  'Duration_11.6.8': 250,
#  'Duration_11.7.8': 251,
#  'Duration_12.0.8': 252,
#  'Position_0': 253,
#  'Position_1': 254,
#  'Position_2': 255,
#  'Position_3': 256,
#  'Position_4': 257,
#  'Position_5': 258,
#  'Position_6': 259,
#  'Position_7': 260,
#  'Position_8': 261,
#  'Position_9': 262,
#  'Position_10': 263,
#  'Position_11': 264,
#  'Position_12': 265,
#  'Position_13': 266,
#  'Position_14': 267,
#  'Position_15': 268,
#  'Position_16': 269,
#  'Position_17': 270,
#  'Position_18': 271,
#  'Position_19': 272,
#  'Position_20': 273,
#  'Position_21': 274,
#  'Position_22': 275,
#  'Position_23': 276,
#  'Position_24': 277,
#  'Position_25': 278,
#  'Position_26': 279,
#  'Position_27': 280,
#  'Position_28': 281,
#  'Position_29': 282,
#  'Position_30': 283,
#  'Position_31': 284,
#  'Position_32': 285,
#  'Position_33': 286,
#  'Position_34': 287,
#  'Position_35': 288,
#  'Position_36': 289,
#  'Position_37': 290,
#  'Position_38': 291,
#  'Position_39': 292,
#  'Position_40': 293,
#  'Position_41': 294,
#  'Position_42': 295,
#  'Position_43': 296,
#  'Position_44': 297,
#  'Position_45': 298,
#  'Position_46': 299,
#  'Position_47': 300,
#  'Position_48': 301,
#  'Position_49': 302,
#  'Position_50': 303,
#  'Position_51': 304,
#  'Position_52': 305,
#  'Position_53': 306,
#  'Position_54': 307,
#  'Position_55': 308,
#  'Position_56': 309,
#  'Position_57': 310,
#  'Position_58': 311,
#  'Position_59': 312,
#  'Position_60': 313,
#  'Position_61': 314,
#  'Position_62': 315,
#  'Position_63': 316,
#  'Chord_C:min': 317,
#  'Chord_C#:min': 318,
#  'Chord_D:min': 319,
#  'Chord_D#:min': 320,
#  'Chord_E:min': 321,
#  'Chord_F:min': 322,
#  'Chord_F#:min': 323,
#  'Chord_G:min': 324,
#  'Chord_G#:min': 325,
#  'Chord_A:min': 326,
#  'Chord_A#:min': 327,
#  'Chord_B:min': 328,
#  'Chord_C:maj': 329,
#  'Chord_C#:maj': 330,
#  'Chord_D:maj': 331,
#  'Chord_D#:maj': 332,
#  'Chord_E:maj': 333,
#  'Chord_F:maj': 334,
#  'Chord_F#:maj': 335,
#  'Chord_G:maj': 336,
#  'Chord_G#:maj': 337,
#  'Chord_A:maj': 338,
#  'Chord_A#:maj': 339,
#  'Chord_B:maj': 340,
#  'Chord_C:dim': 341,
#  'Chord_C#:dim': 342,
#  'Chord_D:dim': 343,
#  'Chord_D#:dim': 344,
#  'Chord_E:dim': 345,
#  'Chord_F:dim': 346,
#  'Chord_F#:dim': 347,
#  'Chord_G:dim': 348,
#  'Chord_G#:dim': 349,
#  'Chord_A:dim': 350,
#  'Chord_A#:dim': 351,
#  'Chord_B:dim': 352,
#  'Chord_C:aug': 353,
#  'Chord_C#:aug': 354,
#  'Chord_D:aug': 355,
#  'Chord_D#:aug': 356,
#  'Chord_E:aug': 357,
#  'Chord_F:aug': 358,
#  'Chord_F#:aug': 359,
#  'Chord_G:aug': 360,
#  'Chord_G#:aug': 361,
#  'Chord_A:aug': 362,
#  'Chord_A#:aug': 363,
#  'Chord_B:aug': 364,
#  'Chord_C:sus2': 365,
#  'Chord_C#:sus2': 366,
#  'Chord_D:sus2': 367,
#  'Chord_D#:sus2': 368,
#  'Chord_E:sus2': 369,
#  'Chord_F:sus2': 370,
#  'Chord_F#:sus2': 371,
#  'Chord_G:sus2': 372,
#  'Chord_G#:sus2': 373,
#  'Chord_A:sus2': 374,
#  'Chord_A#:sus2': 375,
#  'Chord_B:sus2': 376,
#  'Chord_C:sus4': 377,
#  'Chord_C#:sus4': 378,
#  'Chord_D:sus4': 379,
#  'Chord_D#:sus4': 380,
#  'Chord_E:sus4': 381,
#  'Chord_F:sus4': 382,
#  'Chord_F#:sus4': 383,
#  'Chord_G:sus4': 384,
#  'Chord_G#:sus4': 385,
#  'Chord_A:sus4': 386,
#  'Chord_A#:sus4': 387,
#  'Chord_B:sus4': 388,
#  'Chord_C:7dom': 389,
#  'Chord_C#:7dom': 390,
#  'Chord_D:7dom': 391,
#  'Chord_D#:7dom': 392,
#  'Chord_E:7dom': 393,
#  'Chord_F:7dom': 394,
#  'Chord_F#:7dom': 395,
#  'Chord_G:7dom': 396,
#  'Chord_G#:7dom': 397,
#  'Chord_A:7dom': 398,
#  'Chord_A#:7dom': 399,
#  'Chord_B:7dom': 400,
#  'Chord_C:7min': 401,
#  'Chord_C#:7min': 402,
#  'Chord_D:7min': 403,
#  'Chord_D#:7min': 404,
#  'Chord_E:7min': 405,
#  'Chord_F:7min': 406,
#  'Chord_F#:7min': 407,
#  'Chord_G:7min': 408,
#  'Chord_G#:7min': 409,
#  'Chord_A:7min': 410,
#  'Chord_A#:7min': 411,
#  'Chord_B:7min': 412,
#  'Chord_C:7maj': 413,
#  'Chord_C#:7maj': 414,
#  'Chord_D:7maj': 415,
#  'Chord_D#:7maj': 416,
#  'Chord_E:7maj': 417,
#  'Chord_F:7maj': 418,
#  'Chord_F#:7maj': 419,
#  'Chord_G:7maj': 420,
#  'Chord_G#:7maj': 421,
#  'Chord_A:7maj': 422,
#  'Chord_A#:7maj': 423,
#  'Chord_B:7maj': 424,
#  'Chord_C:7halfdim': 425,
#  'Chord_C#:7halfdim': 426,
#  'Chord_D:7halfdim': 427,
#  'Chord_D#:7halfdim': 428,
#  'Chord_E:7halfdim': 429,
#  'Chord_F:7halfdim': 430,
#  'Chord_F#:7halfdim': 431,
#  'Chord_G:7halfdim': 432,
#  'Chord_G#:7halfdim': 433,
#  'Chord_A:7halfdim': 434,
#  'Chord_A#:7halfdim': 435,
#  'Chord_B:7halfdim': 436,
#  'Chord_C:7dim': 437,
#  'Chord_C#:7dim': 438,
#  'Chord_D:7dim': 439,
#  'Chord_D#:7dim': 440,
#  'Chord_E:7dim': 441,
#  'Chord_F:7dim': 442,
#  'Chord_F#:7dim': 443,
#  'Chord_G:7dim': 444,
#  'Chord_G#:7dim': 445,
#  'Chord_A:7dim': 446,
#  'Chord_A#:7dim': 447,
#  'Chord_B:7dim': 448,
#  'Chord_C:7aug': 449,
#  'Chord_C#:7aug': 450,
#  'Chord_D:7aug': 451,
#  'Chord_D#:7aug': 452,
#  'Chord_E:7aug': 453,
#  'Chord_F:7aug': 454,
#  'Chord_F#:7aug': 455,
#  'Chord_G:7aug': 456,
#  'Chord_G#:7aug': 457,
#  'Chord_A:7aug': 458,
#  'Chord_A#:7aug': 459,
#  'Chord_B:7aug': 460,
#  'Chord_C:9maj': 461,
#  'Chord_C#:9maj': 462,
#  'Chord_D:9maj': 463,
#  'Chord_D#:9maj': 464,
#  'Chord_E:9maj': 465,
#  'Chord_F:9maj': 466,
#  'Chord_F#:9maj': 467,
#  'Chord_G:9maj': 468,
#  'Chord_G#:9maj': 469,
#  'Chord_A:9maj': 470,
#  'Chord_A#:9maj': 471,
#  'Chord_B:9maj': 472,
#  'Chord_C:9min': 473,
#  'Chord_C#:9min': 474,
#  'Chord_D:9min': 475,
#  'Chord_D#:9min': 476,
#  'Chord_E:9min': 477,
#  'Chord_F:9min': 478,
#  'Chord_F#:9min': 479,
#  'Chord_G:9min': 480,
#  'Chord_G#:9min': 481,
#  'Chord_A:9min': 482,
#  'Chord_A#:9min': 483,
#  'Chord_B:9min': 484,
#  'Tempo_40.0': 485,
#  'Tempo_46.77': 486,
#  'Tempo_53.55': 487,
#  'Tempo_60.32': 488,
#  'Tempo_67.1': 489,
#  'Tempo_73.87': 490,
#  'Tempo_80.65': 491,
#  'Tempo_87.42': 492,
#  'Tempo_94.19': 493,
#  'Tempo_100.97': 494,
#  'Tempo_107.74': 495,
#  'Tempo_114.52': 496,
#  'Tempo_121.29': 497,
#  'Tempo_128.06': 498,
#  'Tempo_134.84': 499,
#  'Tempo_141.61': 500,
#  'Tempo_148.39': 501,
#  'Tempo_155.16': 502,
#  'Tempo_161.94': 503,
#  'Tempo_168.71': 504,
#  'Tempo_175.48': 505,
#  'Tempo_182.26': 506,
#  'Tempo_189.03': 507,
#  'Tempo_195.81': 508,
#  'Tempo_202.58': 509,
#  'Tempo_209.35': 510,
#  'Tempo_216.13': 511,
#  'Tempo_222.9': 512,
#  'Tempo_229.68': 513,
#  'Tempo_236.45': 514,
#  'Tempo_243.23': 515,
#  'Tempo_250.0': 516}

# %%
def token_obj(token_str):
    name, value = token_str.split("_")
    # try:
    #     value = float(value)
    # except (ValueError, TypeError):
    #     pass

    # to the same chord format as remi_dataset codes
    # Chord_G#_m7
    # Chord_B:9maj

    # if "Pitch" in name:
    #     name = name.replace("Pitch", "Note_Pitch")

    # if "Velocity" in name:
    #     name = name.replace("Velocity", "Note_Velocity")

    # if "Duration" in name:
    #     name = name.replace("Duration", "Note_Duration")

    # if "Chord" in name:
    #     name = name.replace(":", "_")

    # if "Position" in name:
    #     name = name.replace("Position", "Beat")

    return { "name": name, "value": value }


def to_pickle(src, dest):
    z = tokenizer.encode(src)[0]
    tokens = [token_obj(_) for _ in z.tokens]
    bar_ids = [i for i, x in enumerate(z.ids) if x == tokenizer.vocab["Bar_None"]]

    with open(dest, 'wb') as handle:
        pickle.dump((bar_ids, tokens), handle, protocol=pickle.HIGHEST_PROTOCOL)

# to_pickle("jazz/midi/0.mid", "jazz/pickles/0.pkl")

# %%
for name in tqdm(os.listdir("jazz/midi")):
    dest = os.path.join("jazz/pickles", name.replace(".mid", ".pkl"))
    src = os.path.join("jazz/midi", name)
    to_pickle(src, dest)
# Out:
# 100%|██████████| 1994/1994 [01:01<00:00, 32.30it/s]

# %%
from sklearn.model_selection import train_test_split

all_songs = list(os.listdir("jazz/pickles"))
train, valid = train_test_split(all_songs, test_size=0.1)
valid, test = train_test_split(valid, test_size=0.5)

with open("jazz/meta/train.pieces.pkl", 'wb') as handle:
    pickle.dump(train, handle)

with open("jazz/meta/valid.pieces.pkl", 'wb') as handle:
    pickle.dump(valid, handle)

with open("jazz/meta/test.pieces.pkl", 'wb') as handle:
    pickle.dump(test, handle)

# %%
pickle.load(open('jazz/meta/train.pieces.pkl', 'rb'))[0:10]
# Out:
# ['865.pkl',
#  '146.pkl',
#  '1388.pkl',
#  '428.pkl',
#  '1024.pkl',
#  '1524.pkl',
#  '802.pkl',
#  '1906.pkl',
#  '889.pkl',
#  '233.pkl']

# %%
ids, tks = pickle.load(open('jazz/pickles/5.pkl', 'rb'))
tks[0:20], ids[0:10]
# [_ for _ in tks if "Chord" in _["name"]]
# Out:
# ([{'name': 'Bar', 'value': 'None'},
#   {'name': 'Beat', 'value': '0'},
#   {'name': 'Tempo', 'value': '121.29'},
#   {'name': 'Beat', 'value': '16'},
#   {'name': 'Tempo', 'value': '46.77'},
#   {'name': 'Beat', 'value': '21'},
#   {'name': 'Note_Pitch', 'value': '41'},
#   {'name': 'Note_Velocity', 'value': '59'},
#   {'name': 'Note_Duration', 'value': '0.3.16'},
#   {'name': 'Beat', 'value': '23'},
#   {'name': 'Note_Pitch', 'value': '48'},
#   {'name': 'Note_Velocity', 'value': '59'},
#   {'name': 'Note_Duration', 'value': '0.1.16'},
#   {'name': 'Beat', 'value': '24'},
#   {'name': 'Note_Pitch', 'value': '53'},
#   {'name': 'Note_Velocity', 'value': '63'},
#   {'name': 'Note_Duration', 'value': '0.2.16'},
#   {'name': 'Beat', 'value': '25'},
#   {'name': 'Note_Pitch', 'value': '58'},
#   {'name': 'Note_Velocity', 'value': '55'}],
#  [0, 134, 282, 508, 668, 860, 1022, 1285, 1521, 1772])
